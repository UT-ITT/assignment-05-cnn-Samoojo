# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import random

# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomContrast, RandomBrightness

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import pre-trained model
from keras.applications.vgg16 import VGG16

# include only those gestures
CONDITIONS = ['like', 'stop']

# image size
IMG_SIZE = 64
SIZE = (IMG_SIZE, IMG_SIZE)

# number of color channels we want to use
# set to 1 to convert to grayscale
# set to 3 to use color images
COLOR_CHANNELS = 3

PATH = './gesture_dataset_sample'

# %% [markdown]
# ## helper function to load and parse annotations

# %%
annotations = dict()

for condition in CONDITIONS:
    with open(f'{PATH}/_annotations/{condition}.json') as f:
        annotations[condition] = json.load(f)

# %%
# pretty-print first element
#000484ab-5fd0-49b8-9253-23a22b71d7b1
print(json.dumps(annotations['like']['0014182f-d756-42b3-896c-c52de76926bb'], indent=2))
# Out:
# {
#   "bboxes": [
#     [
#       0.38056273,
#       0.35650891,
#       0.17322347,
#       0.10461114
#     ]
#   ],
#   "labels": [
#     "like"
#   ],
#   "landmarks": [
#     [
#       [
#         0.5497169170918876,
#         0.4276043615779976
#       ],
#       [
#         0.5218336293004483,
#         0.40536586667786917
#       ],
#       [
#         0.48288133220125257,
#         0.3930262243722419
#       ],
#       [
#         0.4501841862302019,
#         0.37981099195030416
#       ],
#       [
#         0.44251365410099686,
#         0.36620499322043343
#       ],
#       [
#         0.43138297470865106,
#         0.406093902776592
#       ],
#       [
#         0.4072660997339628,
#         0.4073950234480344
#       ],
#       [
#         0.42588200316326846,
#         0.40612291879594015
#       ],
#       [
#         0.4441470003072778,
#         0.4049221293588555
#       ],
#       [
#         0.4314493576491367,
#         0.4212979654419442
#       ],
#       [
#         0.42096276272263283,
#         0.4180224457320293
#       ],
#       [
#         0.43966095717106257,
#         0.4163441895714394
#       ],
#       [
#         0.45584443128098306,
#         0.41643247458990734
#       ],
#       [
#         0.4399742832485622,
#         0.4347478484477659
#       ],
#       [
#         0.43512361573721164,
#         0.42874760405890505
#       ],
#       [
#         0.44966112930536684,
#         0.42732603739798153
#       ],
#       [
#         0.46521777606118425,
#         0.42773384627175054
#       ],
#       [
#         0.4497130758396873,
#         0.44628828496441647
#       ],
#       [
#         0.4430629908914239,
#         0.4396031525669027
#       ],
#       [
#         0.4567531364734271,
#         0.4381686665415549
#       ],
#       [
#         0.46957149131418796,
#         0.43870709196828805
#       ]
#     ]
#   ],
#   "leading_conf": 1.0,
#   "leading_hand": "left",
#   "user_id": "6886e38c0576360baddef25fad3c0934be1dc0e192caa1c35a1785b50bd54118"
# }

# %% [markdown]
# ## helper function to pre-process images (color channel conversion and resizing)

# %%
def preprocess_image(img):
    if COLOR_CHANNELS == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_resized = cv2.resize(img, SIZE)
    return img_resized

# %% [markdown]
# ## load images and annotations

# %%
images = [] # stores actual image data
labels = [] # stores labels (as integer - because this is what our network needs)
label_names = [] # maps label ints to their actual categories so we can understand predictions later

# loop over all conditions
# loop over all files in the condition's directory
# read the image and corresponding annotation
# crop image to the region of interest
# preprocess image
# store preprocessed image and label in corresponding lists
for condition in CONDITIONS:
    for filename in tqdm(os.listdir(f'{PATH}/{condition}'), disable=True):
        # extract unique ID from file name
        UID = filename.split('.')[0]
        img = cv2.imread(f'{PATH}/{condition}/{filename}')
        
        # get annotation from the dict we loaded earlier
        try:
            annotation = annotations[condition][UID]
        except Exception as e:
            print(e)
            continue
        
        # iterate over all hands annotated in the image
        for i, bbox in enumerate(annotation['bboxes']):
            # annotated bounding boxes are in the range from 0 to 1
            # therefore we have to scale them to the image size
            x1 = int(bbox[0] * img.shape[1])
            y1 = int(bbox[1] * img.shape[0])
            w = int(bbox[2] * img.shape[1])
            h = int(bbox[3] * img.shape[0])
            x2 = x1 + w
            y2 = y1 + h
            
            # crop image to the bounding box and apply pre-processing
            crop = img[y1:y2, x1:x2]
            preprocessed = preprocess_image(crop)
            
            # get the annotated hand's label
            # if we have not seen this label yet, add it to the list of labels
            label = annotation['labels'][i]
            if label not in label_names:
                label_names.append(label)
            
            label_index = label_names.index(label)
            
            images.append(preprocessed)
            labels.append(label_index)

# %% [markdown]
# ## let's have a look at one of the images

# %%
plt.imshow(random.sample(images, 1)[0])
#plt.imshow(random.sample(images, 1)[0], cmap='gray')

# %% [markdown]
# ## split data set into train and test
#
# x is for the actual data, y is for the label (this is convention)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 512
# 128
# 512
# 128

# %% [markdown]
# ## transform data sets into a format compatible with our neural network
#
# image data has to be a numpy array with following dimensions: [image_id, y_axis, x_axis, color_channels]
#
# furthermore, scale all values to a range of 0 to 1
#
# training data has to be converted to a categorial vector ("one hot"):
#
# [3] --> [0, 0, 0, 1, 0, ..., 0]

# %%
# Convert to float
X_train = np.array(X_train).astype('float32')
# Normalization [0,1]
X_train = X_train / 255.

X_test = np.array(X_test).astype('float32')
X_test = X_test / 255.


# Convert interger class labels in to one hot vector
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# rename for demonstration purposes
train_label = y_train_one_hot
test_label = y_test_one_hot

X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)

print(X_train.shape, X_test.shape, train_label.shape, test_label.shape)
# Out:
# (512, 64, 64, 3) (128, 64, 64, 3) (512, 3) (128, 3)

# %%
# variables for hyperparameters
batch_size = 8 
epochs = 50 
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'qweryuqwioreyow'
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# Randomly disables 20% of neurons during each training step
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs

# If validation loss stops improving for 2 epochs, multiply  the learning rate by 0.2 (slow down/fine tune)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
# if validation loss doesn't improve for 3 epchs, stop training entierly
stop_early = EarlyStopping(monitor='val_loss', patience=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 21
#      17 #model.add(RandomBrightness(0.1))
#      18 #model.add(RandomRotation(0.2))
#      19
#      20 # first, we add some convolution layers followed by max pooling
# ---> 21 model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
#      22 model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))
#      23
#      24 model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
#
# File ~/Desktop/todo/Interaction/assignment-05-cnn-Samoojo/venv/lib/python3.13/site-packages/keras/src/layers/convolutional/conv2d.py:118, in Conv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#      98 def __init__(
#      99     self,
#     100     filters,
#    (...)    116     **kwargs,
#     117 ):
# --> 118     super().__init__(
#     119         rank=2,
#     120         filters=filters,
#     121         kernel_size=kernel_size,
#     122         strides=strides,
#     123         padding=padding,
#     124         data_format=data_format,
#     125         dilation_rate=dilation_rate,
#     126         groups=groups,
#     127         activation=activation,
#     128         use_bias=use_bias,
#     129         kernel_initializer=kernel_initializer,
#     130         bias_initializer=bias_initializer,
#     131         kernel_regularizer=kernel_regularizer,
#     132         bias_regularizer=bias_regularizer,
#     133         activity_regularizer=activity_regularizer,
#     134         kernel_constraint=kernel_constraint,
#     135         bias_constraint=bias_constraint,
#     136         **kwargs,
#     137     )
#
# File ~/Desktop/todo/Interaction/assignment-05-cnn-Samoojo/venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:124, in BaseConv.__init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, **kwargs)
#     122 self.padding = standardize_padding(padding, allow_causal=rank == 1)
#     123 self.data_format = standardize_data_format(data_format)
# --> 124 self.activation = activations.get(activation)
#     125 self.use_bias = use_bias
#     126 self.kernel_initializer = initializers.get(kernel_initializer)
#
# File ~/Desktop/todo/Interaction/assignment-05-cnn-Samoojo/venv/lib/python3.13/site-packages/keras/src/activations/__init__.py:128, in get(identifier)
#     126 if callable(obj):
#     127     return obj
# --> 128 raise ValueError(
#     129     f"Could not interpret activation function identifier: {identifier}"
#     130 )
#
# ValueError: Could not interpret activation function identifier: qweryuqwioreyow

# %% [markdown]
# ## now, we can train the model using the fit() function
# ## this will take a while

# %%
history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4238 - loss: 1.0392 - val_accuracy: 0.3203 - val_loss: 1.1969 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5918 - loss: 0.8933 - val_accuracy: 0.6562 - val_loss: 0.8935 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6855 - loss: 0.7280 - val_accuracy: 0.7344 - val_loss: 0.7420 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7422 - loss: 0.7025 - val_accuracy: 0.8359 - val_loss: 0.5158 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8359 - loss: 0.4176 - val_accuracy: 0.8906 - val_loss: 0.4628 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8887 - loss: 0.3129 - val_accuracy: 0.8203 - val_loss: 0.5997 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9160 - loss: 0.2417 - val_accuracy: 0.8672 - val_loss: 0.4367 - learning_rate: 0.0010
# Epoch 8/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9355 - loss: 0.2023 - val_accuracy: 0.9375 - val_loss: 0.2700 - learning_rate: 0.0010
# Epoch 9/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9258 - loss: 0.2115 - val_accuracy: 0.9219 - val_loss: 0.2538 - learning_rate: 0.0010
# Epoch 10/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9629 - loss: 0.0956 - val_accuracy: 0.9375 - val_loss: 0.2885 - learning_rate: 0.0010
# Epoch 11/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9570 - loss: 0.1387 - val_accuracy: 0.8906 - val_loss: 0.3164 - learning_rate: 0.0010
# Epoch 12/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9727 - loss: 0.0771 - val_accuracy: 0.9375 - val_loss: 0.2390 - learning_rate: 2.0000e-04
# Epoch 13/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9824 - loss: 0.0583 - val_accuracy: 0.9375 - val_loss: 0.2348 - learning_rate: 2.0000e-04
# Epoch 14/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9824 - loss: 0.0507 - val_accuracy: 0.9531 - val_loss: 0.2470 - learning_rate: 2.0000e-04
# Epoch 15/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9805 - loss: 0.0465 - val_accuracy: 0.9531 - val_loss: 0.2286 - learning_rate: 2.0000e-04
# Epoch 16/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9941 - loss: 0.0345 - val_accuracy: 0.9453 - val_loss: 0.2253 - learning_rate: 2.0000e-04
# Epoch 17/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9922 - loss: 0.0243 - val_accuracy: 0.9375 - val_loss: 0.2357 - learning_rate: 2.0000e-04
# Epoch 18/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9961 - loss: 0.0208 - val_accuracy: 0.9531 - val_loss: 0.2284 - learning_rate: 2.0000e-04
# Epoch 19/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9902 - loss: 0.0226 - val_accuracy: 0.9531 - val_loss: 0.2375 - learning_rate: 1.0000e-04

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_5 (RandomFlip)      │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_5               │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (8, 3)                 │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 296,843 (1.13 MB)
#  Trainable params: 98,947 (386.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 197,896 (773.04 KB)

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %% [markdown]
# ## saving the model
#
# the function will create a directory for your model and save structure and weights in there
#
# sometimes you will see the .h5 format being used - even though this is a bit faster and needs less space, it comes with its limitations and isn't used that much any more

# %%
model.save('gesture_recognition.keras')

# and this is how you load the model
# model = keras.models.load_model("gesture_recognition.keras")

# %% [markdown]
# ## visualize classification results with a confusion matrix

# %%
# let the model make predictions for our test data
y_predictions = model.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# before [[4.58215363e-05 9.99802232e-01 1.51986795e-04]
#  [9.99991894e-01 1.12431769e-06 7.01890212e-06]
#  [9.99935031e-01 3.31120646e-05 3.17725171e-05]
#  [1.18765759e-03 9.98402715e-01 4.09511762e-04]
#  [1.70056778e-03 9.97720242e-01 5.79182524e-04]
#  [9.77415025e-01 3.92829673e-03 1.86567828e-02]
#  [9.94007349e-01 3.36482917e-04 5.65609382e-03]
#  [9.77015078e-01 1.64208487e-02 6.56413427e-03]
#  [9.89625394e-01 9.74042993e-03 6.34230208e-04]
#  [3.21573578e-02 9.56279397e-01 1.15631819e-02]
#  [3.04508526e-02 4.63006869e-02 9.23248470e-01]
#  [9.99960005e-01 9.44926705e-06 3.06305519e-05]
#  [5.10612062e-06 9.99926925e-01 6.79078294e-05]
#  [8.00013222e-05 9.74474847e-01 2.54450720e-02]
#  [8.69848609e-01 1.26839280e-01 3.31207435e-03]
#  [7.70359278e-01 4.45402004e-02 1.85100466e-01]
#  [5.15418686e-02 1.17015990e-03 9.47287917e-01]
#  [9.48273286e-04 2.96588296e-05 9.99022007e-01]
#  [9.99996543e-01 3.05612184e-06 3.60827045e-07]
#  [1.21849768e-01 7.38534424e-03 8.70764971e-01]
#  [9.99615610e-01 2.68909615e-04 1.15417701e-04]
#  [8.41263413e-01 6.52450249e-02 9.34914947e-02]
#  [7.65192807e-01 1.74642801e-01 6.01644181e-02]
#  [1.10114418e-01 3.34986160e-03 8.86535823e-01]
#  [9.99999881e-01 5.90145852e-08 9.81135457e-08]
#  [6.58818972e-05 2.28101521e-06 9.99931812e-01]
#  [1.06634367e-02 3.57120857e-02 9.53624487e-01]
#  [1.47104962e-02 5.95342880e-03 9.79336143e-01]
#  [1.90361089e-03 9.91122782e-01 6.97359210e-03]
#  [2.90755276e-02 3.84156778e-02 9.32508886e-01]
#  [4.29739118e-01 7.63234589e-03 5.62628508e-01]
#  [1.31209745e-05 9.99936223e-01 5.06674369e-05]
#  [9.76674378e-01 1.25498399e-02 1.07758222e-02]
#  [9.99975383e-01 2.41114503e-05 6.47452111e-07]
#  [9.99554813e-01 3.47663270e-04 9.75192161e-05]
#  [9.99996305e-01 2.00251816e-06 1.61033358e-06]
#  [1.03012554e-03 9.98451531e-01 5.18406159e-04]
#  [7.13937700e-01 5.64510049e-03 2.80417174e-01]
#  [9.99949217e-01 2.52899317e-05 2.54555125e-05]
#  [9.32160318e-01 3.19134444e-04 6.75206333e-02]
#  [2.43169948e-01 4.11071954e-03 7.52719402e-01]
#  [4.20335010e-02 5.33247367e-02 9.04641688e-01]
#  [1.17037074e-04 9.98986423e-01 8.96541344e-04]
#  [5.24813756e-02 4.14653607e-02 9.06053245e-01]
#  [9.99783933e-01 1.74302550e-04 4.18499294e-05]
#  [1.44699430e-02 9.19162333e-01 6.63677454e-02]
#  [1.45535199e-02 9.84493971e-01 9.52471746e-04]
#  [9.99968469e-01 4.17847787e-07 3.10833129e-05]
#  [6.06847461e-03 3.71756149e-03 9.90213990e-01]
#  [9.98628557e-01 1.67926017e-04 1.20346097e-03]
#  [2.76211929e-03 9.96885777e-01 3.52110394e-04]
#  [3.23848315e-02 9.64222074e-01 3.39318928e-03]
#  [1.20009528e-02 9.40312743e-01 4.76863682e-02]
#  [9.99879718e-01 2.87536659e-05 9.15565688e-05]
#  [5.72421789e-01 3.89212638e-01 3.83656360e-02]
#  [9.99542058e-01 9.11148891e-06 4.48875595e-04]
#  [2.13705257e-01 7.84411788e-01 1.88286102e-03]
#  [7.65866460e-03 5.75535698e-04 9.91765797e-01]
#  [3.95137668e-02 9.59706903e-01 7.79338880e-04]
#  [8.86036456e-01 1.13715202e-01 2.48365657e-04]
#  [6.24527747e-04 8.53081729e-05 9.99290168e-01]
#  [9.93106842e-01 1.01211527e-03 5.88107388e-03]
#  [1.45201227e-02 4.76535293e-04 9.85003471e-01]
#  [9.99827862e-01 1.55389880e-05 1.56612135e-04]
#  [1.23689026e-01 1.17341531e-02 8.64576817e-01]
#  [5.93004972e-02 8.16405751e-04 9.39883053e-01]
#  [9.89093065e-01 7.58089870e-03 3.32604209e-03]
#  [3.78152495e-03 9.93541837e-01 2.67665088e-03]
#  [9.99418437e-01 3.07410373e-04 2.74141523e-04]
#  [9.09338176e-01 8.66907015e-02 3.97117576e-03]
#  [3.98837961e-03 2.79761298e-04 9.95731890e-01]
#  [1.10984556e-02 9.78762567e-01 1.01388860e-02]
#  [9.99987125e-01 7.13679754e-07 1.21902840e-05]
#  [1.29109295e-03 9.97908235e-01 8.00718786e-04]
#  [9.75822508e-01 2.26313286e-02 1.54613110e-03]
#  [1.44365092e-03 6.56018819e-05 9.98490751e-01]
#  [3.54837812e-02 6.17350757e-01 3.47165495e-01]
#  [6.31351350e-03 5.46435952e-01 4.47250485e-01]
#  [4.18471172e-02 1.22325756e-02 9.45920348e-01]
#  [9.98954296e-01 7.55370202e-05 9.70237888e-04]
#  [9.39716637e-01 5.44473156e-02 5.83610730e-03]
#  [3.68483318e-03 1.85412049e-04 9.96129751e-01]
#  [1.78791466e-04 2.51771035e-05 9.99796093e-01]
#  [9.99943376e-01 1.81308678e-05 3.85204476e-05]
#  [7.64790893e-05 9.99898374e-01 2.51583879e-05]
#  [1.88473801e-04 9.99744296e-01 6.73025206e-05]
#  [9.00458336e-01 9.50451940e-02 4.49650083e-03]
#  [9.99994993e-01 3.30977400e-06 1.69502755e-06]
#  [9.82485175e-01 1.18311855e-03 1.63316540e-02]
#  [1.16599835e-02 2.35952815e-04 9.88104045e-01]
#  [3.76215667e-01 7.69873783e-02 5.46796978e-01]
#  [3.57162580e-02 2.71777242e-01 6.92506492e-01]
#  [9.99501586e-01 3.87881038e-04 1.10570705e-04]
#  [1.53908104e-01 2.40937416e-02 8.21998179e-01]
#  [5.98958246e-02 9.26487565e-01 1.36167053e-02]
#  [9.92711544e-01 5.80264907e-03 1.48572749e-03]
#  [2.90520489e-03 9.93265033e-01 3.82974115e-03]
#  [9.23005771e-03 9.80473459e-01 1.02966083e-02]
#  [9.94627595e-01 6.98031567e-04 4.67438903e-03]
#  [9.99973118e-01 1.33161802e-06 2.55939503e-05]
#  [9.99154806e-01 7.36908987e-04 1.08289787e-04]
#  [1.60469511e-03 1.94674940e-04 9.98200655e-01]
#  [1.44196686e-03 8.29950441e-05 9.98475075e-01]
#  [7.80593082e-02 8.86245787e-01 3.56949493e-02]
#  [3.08795758e-02 1.85064748e-02 9.50613856e-01]
#  [9.99450088e-01 3.27294583e-05 5.17262262e-04]
#  [3.17459673e-01 1.82502181e-03 6.80715263e-01]
#  [9.99998927e-01 7.91002208e-07 2.16114998e-07]
#  [9.98463035e-01 1.26017534e-04 1.41098152e-03]
#  [9.99995589e-01 7.24487222e-07 3.68774681e-06]
#  [9.99982655e-01 1.48511299e-05 2.49777213e-06]
#  [1.75029673e-02 9.66639817e-01 1.58571098e-02]
#  [7.07390427e-04 1.60638432e-04 9.99131918e-01]
#  [1.20009587e-04 9.99033332e-01 8.46636307e-04]
#  [7.29593541e-03 4.89036174e-05 9.92655158e-01]
#  [2.34608769e-01 7.65379786e-01 1.15273488e-05]
#  [9.86865699e-01 1.30354818e-02 9.88044631e-05]
#  [9.99906957e-01 3.19665633e-05 6.11143914e-05]
#  [1.61923077e-02 1.36630207e-01 8.47177565e-01]
#  [7.86152296e-03 9.39014542e-04 9.91199493e-01]
#  [1.22384587e-03 9.96560454e-01 2.21568230e-03]
#  [4.11561355e-02 6.34654716e-04 9.58209217e-01]
#  [2.19523385e-01 7.26747811e-02 7.07801878e-01]
#  [9.89924848e-01 8.14982969e-03 1.92530779e-03]
#  [4.36973542e-01 1.97142109e-01 3.65884364e-01]
#  [1.37296133e-02 9.62604225e-01 2.36660745e-02]
#  [1.91420934e-03 9.31416869e-01 6.66690096e-02]
#  [3.58514011e-01 2.86854280e-04 6.41199112e-01]]
# probabilities [1 0 0 1 1 0 0 0 0 1 2 0 1 1 0 0 2 2 0 2 0 0 0 2 0 2 2 2 1 2 2 1 0 0 0 0 1
#  0 0 0 2 2 1 2 0 1 1 0 2 0 1 1 1 0 0 0 1 2 1 0 2 0 2 0 2 2 0 1 0 0 2 1 0 1
#  0 2 1 1 2 0 0 2 2 0 1 1 0 0 0 2 2 2 0 2 1 0 1 1 0 0 0 2 2 1 2 0 2 0 0 0 0
#  1 2 1 2 1 0 0 2 2 1 2 2 0 0 1 1 2]

# %% [markdown]
# ## let's test our model in action

# %%
# for mac users: you may have to add time.sleep(1) as the mac camera has a short fade in time. Furthermore possibly it will select your IPhone camera: you can deactivate this
import time
cap = cv2.VideoCapture(0)
time.sleep(1)
ret, frame = cap.read()
if COLOR_CHANNELS == 1:
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
cap.release()
plt.imshow(frame)

# %% [markdown]
# ## manual cropping for demonstration purposes - you can do better!

# %%
cropped = frame[150:400, 300:450]
plt.imshow(cropped)

# %%
resized = cv2.resize(cropped, SIZE)#[20:350, 200:420], SIZE)
plt.imshow(resized)
resized.shape
# Out:
# (64, 64, 3)

# %%
reshaped = resized.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
reshaped.shape
prediction = model.predict(reshaped)

print(label_names[np.argmax(prediction)], np.max(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# stop 1.0

# %%
# Extracts the learned parameters from layer 2 (the first convolution layer)
filters, biases = model.layers[2].get_weights()
# kernel height, kernel width, input channels, num filters -> 64 filters, each 9x9 patch across 3 color channels
print(filters.shape)

fig, axes = plt.subplots(8, 8, figsize=(20, 20))

for i in range(8):
    for j in range(8):
        img = filters[:,:,:,i*8+j] * (1 / np.max(filters))
        axes[i][j].imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.91534954..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.63777983..0.5372024].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4827094..0.36075813].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6326827..0.501635].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71921986..0.5233093].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0166903..0.8742804].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6780254..0.4858065].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7771993..0.77958304].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8741639..0.45275828].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.44508335..0.39425537].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1106983..0.74578404].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7113598..0.44143656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.62048197..0.47620127].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9358158..0.62546337].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5725232..0.51541084].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8263155..0.6036998].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.40445417..0.37768337].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.58098215..0.53876287].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9441582..0.80048305].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.49038061..0.38861972].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6521222..0.61541945].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5410557..0.5766897].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8070166..0.6069447].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.75538546..0.82033443].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.72777075..0.5135392].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.97253454..0.58233356].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6816709..0.48969278].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6633162..0.5904313].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6276788..0.53019947].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7036355..0.39569515].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.79871035..0.51421046].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.94777364..0.71468997].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6740335..0.5380967].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6233169..0.6072015].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.812888..0.8074554].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.03352..0.982054].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71103656..0.5433614].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.50160664..0.62534493].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.97140265..0.8306358].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9008719..0.90706444].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.54803216..0.555675].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1367368..0.8634135].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.79110974..0.70201033].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5882173..0.46162212].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.59376323..0.63903177].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7532148..0.5891115].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71319515..0.6583949].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.68849546..0.59726155].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.65569997..0.4672013].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8722294..0.84479445].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.76060617..0.4951796].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.64314115..0.54359084].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7740286..0.6004398].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.9336788..0.7309487].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.87251925..0.8755628].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.51074797..0.63657737].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0884926..0.8862523].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5668186..0.41466373].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5960193..0.46748102].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0303217..0.8253348].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.45419604..0.35483587].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.60015744..0.45076996].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7342908..0.6291297].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.4642213..0.36768925].
# (9, 9, 3, 64)

# %%
fig, axes = plt.subplots(8, 8, figsize=(20, 20))

for i in range(8):
    for j in range(8):
        #axes[i][j].imshow(filters[:,:,:,i*8+j] * 255, 'gray')
        
        # only channle 0 for demonstration purposes
        kernel = filters[:,:,0,i*8+j]

        #print(kernel.shape)

        gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
        filtered = cv2.filter2D(gray, -1, kernel)

        axes[i][j].imshow(filtered, 'gray')

# %% [markdown]
# ## Transfer Learning
#
# let's use a pre-trained model (VGG16) for our prediction
#
# note that VGG16 needs three color channels

# %%
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'leaky_relu'  # LeakyReLU
layer_count = 2
num_neurons = 256

# load a VGG16 model trained on the imagenet dataset
# include_top=False -> do not include the output layer
# input_tensor -> tells the model about the dimensions of our images (VGG16 needs three color channels)
# pooling -> which type of pooling to use between convolutions; max or avg seem to be the best
VGG = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)), pooling='max')

# we want to use the VGG's original weights -> make those layers untrainable
for layer in VGG.layers:
    layer.trainable = False

# build a new model and add the VGG layers
model_vgg = Sequential()
model_vgg.add(VGG)

# append dense layers at the end
for i in range(layer_count - 1):
    model_vgg.add(Dense(num_neurons, activation=activation))
model_vgg.add(Dropout(0.2))

model_vgg.add(Dense(num_neurons, activation=activation))

# classifier
model_vgg.add(Dense(num_classes, activation='softmax'))

model_vgg.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

# %%
history_vgg = model_vgg.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.7168 - loss: 0.6676 - val_accuracy: 0.8438 - val_loss: 0.4327 - learning_rate: 0.0010
# Epoch 2/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9062 - loss: 0.2540 - val_accuracy: 0.8750 - val_loss: 0.3351 - learning_rate: 0.0010
# Epoch 3/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9453 - loss: 0.1730 - val_accuracy: 0.8594 - val_loss: 0.3213 - learning_rate: 0.0010
# Epoch 4/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9688 - loss: 0.0980 - val_accuracy: 0.9062 - val_loss: 0.2261 - learning_rate: 0.0010
# Epoch 5/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9727 - loss: 0.0822 - val_accuracy: 0.9453 - val_loss: 0.2692 - learning_rate: 0.0010
# Epoch 6/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9668 - loss: 0.0866 - val_accuracy: 0.8359 - val_loss: 0.4696 - learning_rate: 0.0010
# Epoch 7/50
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9844 - loss: 0.0518 - val_accuracy: 0.9062 - val_loss: 0.2803 - learning_rate: 3.0000e-04

# %%
model_vgg.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,308,363 (58.40 MB)
#  Trainable params: 197,891 (773.01 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
#  Optimizer params: 395,784 (1.51 MB)

# %%
loss = history_vgg.history['loss']
val_loss = history_vgg.history['val_loss']
accuracy = history_vgg.history['accuracy']
val_accuracy = history_vgg.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
# let the model make predictions for our training data
y_predictions = model_vgg.predict(X_test)

# we get a 2D numpy array with probabilities for each category
print('before', y_predictions)

# to build a confusion matrix, we have to convert it to classifications
# this can be done by using the argmax() function to set the probability to 1 and the rest to 0
y_predictions = np.argmax(y_predictions, axis=1)

print('probabilities', y_predictions)

# create and plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_predictions)

fig = plt.figure(figsize=(10, 10))

ConfusionMatrixDisplay(conf_matrix, display_labels=label_names).plot(ax=plt.gca())

plt.xticks(rotation=90, ha='center')
pass
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# before [[4.26671794e-03 3.15619707e-01 6.80113554e-01]
#  [1.00000000e+00 2.91347524e-09 8.66360317e-10]
#  [9.26050171e-02 5.48139751e-01 3.59255195e-01]
#  [1.12517015e-03 9.87815440e-01 1.10595319e-02]
#  [3.02893240e-02 9.68104541e-01 1.60620257e-03]
#  [9.98686612e-01 9.83330887e-04 3.30058974e-04]
#  [9.99405921e-01 3.63726460e-04 2.30281861e-04]
#  [9.98229265e-01 3.42165513e-05 1.73639436e-03]
#  [9.99581099e-01 3.45538370e-04 7.33105044e-05]
#  [6.00308340e-05 9.88882661e-01 1.10574467e-02]
#  [6.08417355e-02 2.04658955e-01 7.34499335e-01]
#  [9.99999285e-01 3.57592825e-07 3.09267506e-07]
#  [3.16899991e-06 9.99433219e-01 5.63535199e-04]
#  [5.14870882e-03 9.54129994e-01 4.07212414e-02]
#  [7.81639099e-01 5.15560172e-02 1.66804850e-01]
#  [3.92094906e-03 9.40125883e-01 5.59531972e-02]
#  [7.74036657e-09 1.76076617e-06 9.99998212e-01]
#  [6.37134963e-06 2.03898726e-05 9.99973357e-01]
#  [9.99922216e-01 7.46279111e-05 3.20727531e-06]
#  [1.72480634e-06 6.36675441e-06 9.99991894e-01]
#  [9.36129391e-01 3.39461723e-04 6.35310933e-02]
#  [9.22655582e-01 1.44047914e-02 6.29395545e-02]
#  [9.95370090e-01 1.38326886e-03 3.24658607e-03]
#  [1.30777389e-05 5.79676765e-04 9.99407232e-01]
#  [9.99947429e-01 1.91981271e-05 3.33173266e-05]
#  [8.14952898e-07 2.65839975e-04 9.99733388e-01]
#  [1.48906285e-04 3.76450270e-03 9.96086597e-01]
#  [4.20270408e-06 1.78655653e-04 9.99817133e-01]
#  [7.53537565e-02 1.12229455e-02 9.13423300e-01]
#  [7.70975530e-01 1.84091041e-03 2.27183551e-01]
#  [9.97047664e-06 7.46583682e-05 9.99915421e-01]
#  [4.63124411e-03 9.82788801e-01 1.25799170e-02]
#  [5.41052930e-02 4.35820362e-03 9.41536427e-01]
#  [9.99980032e-01 5.27910572e-07 1.94967379e-05]
#  [9.99715507e-01 1.30639382e-04 1.53816363e-04]
#  [1.41787663e-01 3.88004235e-03 8.54332209e-01]
#  [3.60170588e-06 9.98856723e-01 1.13961229e-03]
#  [9.99650896e-01 1.38190531e-04 2.10949249e-04]
#  [9.95604336e-01 3.64871303e-05 4.35917126e-03]
#  [7.63899148e-01 1.38481632e-01 9.76193324e-02]
#  [5.92176989e-03 3.45103681e-01 6.48974597e-01]
#  [2.70220771e-04 1.85690280e-02 9.81160700e-01]
#  [5.23268282e-05 9.99763846e-01 1.83831042e-04]
#  [6.48341156e-05 1.43010311e-05 9.99920905e-01]
#  [9.99970496e-01 1.88444974e-05 1.07284995e-05]
#  [2.13529042e-04 7.28909075e-01 2.70877451e-01]
#  [2.77656922e-03 9.43492591e-01 5.37307933e-02]
#  [9.99991298e-01 4.23832353e-06 4.43023509e-06]
#  [6.82373923e-07 1.17219679e-05 9.99987602e-01]
#  [9.99852836e-01 4.20319520e-06 1.43086727e-04]
#  [4.29538716e-07 9.99847472e-01 1.52134482e-04]
#  [1.59835748e-04 9.99732673e-01 1.07484608e-04]
#  [2.82906201e-02 7.71502972e-01 2.00206414e-01]
#  [8.78337264e-01 1.39638064e-02 1.07699007e-01]
#  [9.68293130e-01 2.86144459e-05 3.16782445e-02]
#  [9.99963343e-01 3.13968994e-05 5.33285947e-06]
#  [9.99966800e-01 1.22782885e-05 2.09651589e-05]
#  [3.18005448e-07 3.91494314e-06 9.99995708e-01]
#  [5.17673499e-04 9.99315619e-01 1.66674858e-04]
#  [1.78199596e-04 9.92472708e-01 7.34923081e-03]
#  [3.65723827e-06 1.46632243e-04 9.99849737e-01]
#  [9.99998927e-01 1.01590771e-07 9.74097020e-07]
#  [1.64415923e-07 5.15569070e-07 9.99999285e-01]
#  [9.99991417e-01 2.43690033e-06 6.22577545e-06]
#  [1.94266065e-07 8.32536170e-05 9.99916613e-01]
#  [8.13226041e-04 3.08595889e-04 9.98878181e-01]
#  [7.97896028e-01 1.97428793e-01 4.67517413e-03]
#  [1.34151313e-04 9.99544084e-01 3.21747502e-04]
#  [9.99430120e-01 5.62417554e-04 7.33318348e-06]
#  [8.75281751e-01 3.09081655e-03 1.21627353e-01]
#  [9.31110662e-06 9.07851984e-07 9.99989748e-01]
#  [1.95369590e-02 9.80246782e-01 2.16340937e-04]
#  [9.99948978e-01 4.99867892e-05 1.10176529e-06]
#  [9.14757675e-06 9.99924302e-01 6.64666586e-05]
#  [9.96286869e-01 4.73349246e-05 3.66572523e-03]
#  [1.04204950e-07 6.27794798e-05 9.99937057e-01]
#  [7.54471635e-04 9.90900517e-01 8.34497903e-03]
#  [9.54444477e-06 5.50172403e-02 9.44973171e-01]
#  [3.59287296e-05 1.10611188e-06 9.99962986e-01]
#  [9.99987125e-01 1.02857784e-05 2.64479763e-06]
#  [9.79437053e-01 5.21879923e-03 1.53440963e-02]
#  [3.38456198e-06 6.64531108e-05 9.99930143e-01]
#  [2.62612139e-05 1.33288268e-06 9.99972522e-01]
#  [9.59897220e-01 4.36998584e-04 3.96657549e-02]
#  [7.54284974e-06 9.88190234e-01 1.18021695e-02]
#  [1.16814789e-03 9.98089015e-01 7.42745236e-04]
#  [2.02421367e-01 4.85429950e-02 7.49035716e-01]
#  [9.99991417e-01 8.32681417e-06 1.99948076e-07]
#  [1.84210137e-01 7.26684555e-03 8.08522999e-01]
#  [7.13841200e-06 8.87814211e-04 9.99105036e-01]
#  [1.04383059e-01 7.85029113e-01 1.10587887e-01]
#  [1.67458631e-06 4.79336381e-02 9.52064693e-01]
#  [9.99959767e-01 1.42028750e-06 3.88664012e-05]
#  [4.43040743e-04 6.50541158e-04 9.98906374e-01]
#  [1.42152293e-03 9.88957763e-01 9.62060224e-03]
#  [9.99981463e-01 1.26800142e-05 5.91795924e-06]
#  [4.06698609e-06 9.99886274e-01 1.09716151e-04]
#  [5.89118805e-04 9.95541811e-01 3.86918453e-03]
#  [9.99248803e-01 7.21414108e-04 2.97410243e-05]
#  [9.99955833e-01 5.41589043e-06 3.89146880e-05]
#  [9.99999523e-01 4.22392645e-07 1.02152518e-08]
#  [3.44513978e-07 6.60063165e-07 9.99999046e-01]
#  [6.65393252e-09 2.44679268e-05 9.99975622e-01]
#  [1.13271381e-04 9.79693353e-01 2.01933850e-02]
#  [7.95723172e-05 1.35562805e-05 9.99906957e-01]
#  [7.99083054e-01 1.95932657e-01 4.98441234e-03]
#  [1.70188332e-06 9.43288760e-05 9.99903977e-01]
#  [9.99986172e-01 1.32831801e-05 5.43657563e-07]
#  [9.99910533e-01 8.88552822e-05 6.92105971e-07]
#  [9.99995828e-01 3.40773181e-06 7.11598148e-07]
#  [9.99999642e-01 3.08063363e-07 2.83554780e-09]
#  [4.44877505e-01 5.52262962e-01 2.85963062e-03]
#  [1.32935304e-06 9.04405460e-05 9.99908268e-01]
#  [3.63320607e-04 9.17559028e-01 8.20776597e-02]
#  [2.91334374e-07 2.30148635e-05 9.99976695e-01]
#  [7.65023869e-04 9.73880172e-01 2.53548250e-02]
#  [4.58385330e-05 9.94388640e-01 5.56543982e-03]
#  [9.99999404e-01 5.46995238e-07 4.26656328e-08]
#  [9.92034256e-01 6.19523693e-04 7.34615559e-03]
#  [4.21484932e-03 7.24026002e-03 9.88544822e-01]
#  [7.56645068e-06 9.99936819e-01 5.56894774e-05]
#  [2.46842023e-06 2.09475736e-04 9.99788105e-01]
#  [5.38934313e-04 2.24562790e-02 9.77004766e-01]
#  [9.24945902e-03 9.51117754e-01 3.96327898e-02]
#  [9.34826136e-01 1.98671296e-02 4.53066416e-02]
#  [2.93819848e-02 9.68890309e-01 1.72771467e-03]
#  [8.88219452e-04 1.28094018e-01 8.71017754e-01]
#  [2.93039761e-06 1.51157074e-05 9.99982059e-01]]
# probabilities [2 0 1 1 1 0 0 0 0 1 2 0 1 1 0 1 2 2 0 2 0 0 0 2 0 2 2 2 2 0 2 1 2 0 0 2 1
#  0 0 0 2 2 1 2 0 1 1 0 2 0 1 1 1 0 0 0 0 2 1 1 2 0 2 0 2 2 0 1 0 0 2 1 0 1
#  0 2 1 2 2 0 0 2 2 0 1 1 2 0 2 2 1 2 0 2 1 0 1 1 0 0 0 2 2 1 2 0 2 0 0 0 0
#  1 2 1 2 1 1 0 0 2 1 2 2 1 0 1 2 2]
